# %%
# Import Dependencies
import pandas as pd

# %%
csv_path1 = "../Resources/cleaned_species.csv"

# %%
df1 = pd.read_csv(csv_path1, engine='python')

# %%
df1.head()
# Out:
#               Park Name Category    Family         Scientific Name  \
# 0  Acadia National Park   Mammal  Cervidae             Alces alces
# 1  Acadia National Park   Mammal  Cervidae  Odocoileus virginianus
# 2  Acadia National Park   Mammal   Canidae           Canis latrans
# 3  Acadia National Park   Mammal   Canidae             Canis lupus
# 4  Acadia National Park   Mammal   Canidae           Vulpes vulpes
#
#                                         Common Names
# 0                                              Moose
# 1  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2                             Coyote, Eastern Coyote
# 3        Eastern Timber Wolf, Gray Wolf, Timber Wolf
# 4  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...

# %%
park_count = df1.groupby('Park Name')['Category'].count()
park_count
df = pd.DataFrame({'Park Name':park_count.index, 'count':park_count.values})
df
# Out:
#                                          Park Name  count
# 0                             Acadia National Park   1709
# 1                             Arches National Park   1048
# 2                           Badlands National Park   1389
# 3                           Big Bend National Park   2269
# 4                           Biscayne National Park   1726
# 5       Black Canyon of the Gunnison National Park   1106
# 6                       Bryce Canyon National Park   1286
# 7                        Canyonlands National Park   1223
# 8                       Capitol Reef National Park   1566
# 9                   Carlsbad Caverns National Park   1536
# 10                   Channel Islands National Park   1885
# 11                          Congaree National Park   2321
# 12                       Crater Lake National Park   3760
# 13                   Cuyahoga Valley National Park   1941
# 14                      Death Valley National Park   4439
# ...

# %%
sorted = df.sort_values(by='count')
sorted
# Out:
#                                          Park Name  count
# 16                      Dry Tortugas National Park    848
# 42                  Petrified Forest National Park    853
# 24     Great Sand Dunes National Park and Preserve    952
# 34                      Kobuk Valley National Park   1025
# 1                             Arches National Park   1048
# 33                      Kenai Fjords National Park   1057
# 5       Black Canyon of the Gunnison National Park   1106
# 49                Theodore Roosevelt National Park   1165
# 7                        Canyonlands National Park   1223
# 32               Katmai National Park and Preserve   1225
# 38                        Mesa Verde National Park   1243
# 6                       Bryce Canyon National Park   1286
# 15               Denali National Park and Preserve   1320
# 18  Gates Of The Arctic National Park and Preserve   1353
# 2                           Badlands National Park   1389
# ...

# %%
sorted.to_csv('../Resources/park_count.csv', index=False)

# %%
park_count = df1['Park Name'].value_counts()


park_df = park_count.to_frame()
park_df
# Out:
#                                                 Park Name
# Great Smoky Mountains National Park                  6623
# Redwood National Park                                6310
# Shenandoah National Park                             4655
# Death Valley National Park                           4439
# Yellowstone National Park                            3966
# Crater Lake National Park                            3760
# North Cascades National Park                         3363
# Hawaii Volcanoes National Park                       3298
# Rocky Mountain National Park                         3152
# Great Basin National Park                            2653
# Grand Canyon National Park                           2622
# Haleakala National Park                              2580
# Glacier National Park                                2556
# Mammoth Cave National Park                           2499
# Congaree National Park                               2321
# ...

# %%
park_df.rename(columns={"": "Park Name", "Park Name": "Count"})
# Out:
#                                                 Count
# Great Smoky Mountains National Park              6623
# Redwood National Park                            6310
# Shenandoah National Park                         4655
# Death Valley National Park                       4439
# Yellowstone National Park                        3966
# Crater Lake National Park                        3760
# North Cascades National Park                     3363
# Hawaii Volcanoes National Park                   3298
# Rocky Mountain National Park                     3152
# Great Basin National Park                        2653
# Grand Canyon National Park                       2622
# Haleakala National Park                          2580
# Glacier National Park                            2556
# Mammoth Cave National Park                       2499
# Congaree National Park                           2321
# Joshua Tree National Park                        2294
# ...

# %%
df2 = pd.read_csv(csv_path2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\haldu\Group-4-Project-3\.ipynb_checkpoints\new_species.ipynb Cell 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/haldu/Group-4-Project-3/.ipynb_checkpoints/new_species.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> df2 = pd.read_csv(csv_path2)
#
# NameError: name 'csv_path2' is not defined

# %%
df1.head()
# Out:
#   Species ID             Park Name Category         Order    Family  \
# 0  ACAD-1000  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 1  ACAD-1001  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 2  ACAD-1002  Acadia National Park   Mammal     Carnivora   Canidae
# 3  ACAD-1003  Acadia National Park   Mammal     Carnivora   Canidae
# 4  ACAD-1004  Acadia National Park   Mammal     Carnivora   Canidae
#
#           Scientific Name                                       Common Names  \
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2           Canis latrans                             Coyote, Eastern Coyote
# 3             Canis lupus        Eastern Timber Wolf, Gray Wolf, Timber Wolf
# 4           Vulpes vulpes  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...
#
#   Record Status     Occurrence  Nativeness Abundance Seasonality  \
# ...

# %%
df2.head()
# Out:
#   Park Code               Park Name State   Acres  Latitude  Longitude
# 0      ACAD    Acadia National Park    ME   47390     44.35      -68.21
# 1      ARCH    Arches National Park    UT   76519     38.68     -109.57
# 2      BADL  Badlands National Park    SD  242756     43.75     -102.50
# 3      BIBE  Big Bend National Park    TX  801163     29.25     -103.25
# 4      BISC  Biscayne National Park    FL  172924     25.65      -80.08

# %%
df1.columns
# Out:
# Index(['Species ID', 'Park Name', 'Category', 'Order', 'Family',
#        'Scientific Name', 'Common Names', 'Record Status', 'Occurrence',
#        'Nativeness', 'Abundance', 'Seasonality', 'Conservation Status',
#        'Unnamed: 13'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Park Code', 'Park Name', 'State', 'Acres', 'Latitude', 'Longitude '], dtype='object')

# %%
df1.fillna("Nan"=="0", inplace=True)

# %%
df1.head()
# Out:
#   Species ID             Park Name Category         Order    Family  \
# 0  ACAD-1000  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 1  ACAD-1001  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 2  ACAD-1002  Acadia National Park   Mammal     Carnivora   Canidae
# 3  ACAD-1003  Acadia National Park   Mammal     Carnivora   Canidae
# 4  ACAD-1004  Acadia National Park   Mammal     Carnivora   Canidae
#
#           Scientific Name                                       Common Names  \
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2           Canis latrans                             Coyote, Eastern Coyote
# 3             Canis lupus        Eastern Timber Wolf, Gray Wolf, Timber Wolf
# 4           Vulpes vulpes  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...
#
#   Record Status     Occurrence  Nativeness Abundance Seasonality  \
# ...

# %%
new_df1 = df1.drop(["Species ID", "Order", "Occurrence",
       "Nativeness", "Abundance", "Seasonality", "Conservation Status",
       "Conservation Status",
       ],axis=1,)
new_df1
# Out:
#                    Park Name        Category          Family  \
# 0       Acadia National Park          Mammal        Cervidae
# 1       Acadia National Park          Mammal        Cervidae
# 2       Acadia National Park          Mammal         Canidae
# 3       Acadia National Park          Mammal         Canidae
# 4       Acadia National Park          Mammal         Canidae
# ...                      ...             ...             ...
# 119243    Zion National Park  Vascular Plant      Solanaceae
# 119244    Zion National Park  Vascular Plant        Vitaceae
# 119245    Zion National Park  Vascular Plant        Vitaceae
# 119246    Zion National Park  Vascular Plant  Zygophyllaceae
# 119247    Zion National Park  Vascular Plant  Zygophyllaceae
#
#                Scientific Name  \
# 0                  Alces alces
# 1       Odocoileus virginianus
# 2                Canis latrans
# 3                  Canis lupus
# 4                Vulpes vulpes
# ...                        ...
# ...

# %%
new_df1.head()
# Out:
#               Park Name Category    Family         Scientific Name  \
# 0  Acadia National Park   Mammal  Cervidae             Alces alces
# 1  Acadia National Park   Mammal  Cervidae  Odocoileus virginianus
# 2  Acadia National Park   Mammal   Canidae           Canis latrans
# 3  Acadia National Park   Mammal   Canidae             Canis lupus
# 4  Acadia National Park   Mammal   Canidae           Vulpes vulpes
#
#                                         Common Names Record Status Unnamed: 13
# 0                                              Moose      Approved       False
# 1  Northern White-Tailed Deer, Virginia Deer, Whi...      Approved       False
# 2                             Coyote, Eastern Coyote      Approved       False
# 3        Eastern Timber Wolf, Gray Wolf, Timber Wolf      Approved       False
# 4  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...      Approved       False

# %%
main_df = new_df1.drop(["Record Status", "Unnamed: 13"],axis=1,)

# %%
main_df.head()
# Out:
#               Park Name Category    Family         Scientific Name  \
# 0  Acadia National Park   Mammal  Cervidae             Alces alces
# 1  Acadia National Park   Mammal  Cervidae  Odocoileus virginianus
# 2  Acadia National Park   Mammal   Canidae           Canis latrans
# 3  Acadia National Park   Mammal   Canidae             Canis lupus
# 4  Acadia National Park   Mammal   Canidae           Vulpes vulpes
#
#                                         Common Names
# 0                                              Moose
# 1  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2                             Coyote, Eastern Coyote
# 3        Eastern Timber Wolf, Gray Wolf, Timber Wolf
# 4  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...

# %%
main_df.to_csv('../Resources/cleaned_species.csv', index=False)

# %%
df2.head()
# Out:
#   Park Code               Park Name State   Acres  Latitude  Longitude
# 0      ACAD    Acadia National Park    ME   47390     44.35      -68.21
# 1      ARCH    Arches National Park    UT   76519     38.68     -109.57
# 2      BADL  Badlands National Park    SD  242756     43.75     -102.50
# 3      BIBE  Big Bend National Park    TX  801163     29.25     -103.25
# 4      BISC  Biscayne National Park    FL  172924     25.65      -80.08

# %%
df2.to_csv('../Resources/cleaned_park.csv', index=False)

# %%
cleaned_species = main_df
cleaned_species.head()
# Out:
#               Park Name Category    Family         Scientific Name  \
# 0  Acadia National Park   Mammal  Cervidae             Alces alces
# 1  Acadia National Park   Mammal  Cervidae  Odocoileus virginianus
# 2  Acadia National Park   Mammal   Canidae           Canis latrans
# 3  Acadia National Park   Mammal   Canidae             Canis lupus
# 4  Acadia National Park   Mammal   Canidae           Vulpes vulpes
#
#                                         Common Names
# 0                                              Moose
# 1  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2                             Coyote, Eastern Coyote
# 3        Eastern Timber Wolf, Gray Wolf, Timber Wolf
# 4  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...

# %%
cleaned_parks = df2.drop(["Park Code"],axis=1,)
cleaned_parks.head()
# Out:
#                 Park Name State   Acres  Latitude  Longitude
# 0    Acadia National Park    ME   47390     44.35      -68.21
# 1    Arches National Park    UT   76519     38.68     -109.57
# 2  Badlands National Park    SD  242756     43.75     -102.50
# 3  Big Bend National Park    TX  801163     29.25     -103.25
# 4  Biscayne National Park    FL  172924     25.65      -80.08
